# %%
import datetime

import numpy as np
import pandas as pd
import pandas_ta as ta
import seaborn as sns
import tensorflow as tf
import matplotlib.pyplot as plt

from tensorflow.keras import Model, Sequential

from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.losses import MeanSquaredError
from tensorflow.keras.metrics import MeanAbsoluteError

from tensorflow.keras.layers import Dense, Conv1D, LSTM, Lambda, Reshape, RNN, LSTMCell

import warnings
warnings.filterwarnings('ignore')

# %%
bitcoin = pd.read_csv('Bitcoin2.csv', sep=';')
bitcoin = bitcoin.iloc[::-1].reset_index(drop=True)

# %%
bitcoin.set_index(pd.DatetimeIndex(bitcoin["timeHigh"]), inplace=True)
vwap = ta.vwap(high=bitcoin['high'], low=bitcoin['low'], close=bitcoin['close'], volume=bitcoin['volume'])

atr = ta.atr(low=bitcoin['low'], high=bitcoin['high'], close=bitcoin['close'], length=14)
ema = ta.ema(close=bitcoin['close'], length=9)

# %%
cols_to_drop = ['timeOpen', 'timeClose', 'timeLow', 'timestamp', 'name', 'marketCap']
bitcoin = bitcoin.drop(cols_to_drop, axis=1)

# %%
timestamp_s = pd.to_datetime(bitcoin['timeHigh']).map(datetime.datetime.timestamp)
month = 30 * 24 * 60 * 60
bitcoin['month_sin'] = (np.sin(timestamp_s * (2*np.pi/month))).values
bitcoin = bitcoin.drop(['timeHigh'], axis=1)

bitcoin['vwap'] = vwap.values
bitcoin = bitcoin.drop(['volume'], axis=1)
bitcoin['atr'] = atr.values
bitcoin = bitcoin.drop(['low'], axis=1)
bitcoin['ema'] = ema.values
bitcoin = bitcoin.drop(['close'], axis=1)
bitcoin = bitcoin.drop(['open'], axis=1)

# %%
bitcoin.describe().transpose()
# Out:
#            count          mean           std           min           25%  \
# high       364.0  40681.358679  14962.167850  25735.308542  28040.592870
# month_sin  364.0     -0.008517      0.706835     -0.999898     -0.715739
# vwap       364.0  39962.236203  14482.278428  25325.633256  27623.187570
# atr        350.0   1441.826629    979.760619    486.006616    688.793676
# ema        356.0  39910.946035  14344.252567  25808.192306  27428.031445
#
#                     50%           75%           max
# high       35710.173965  46678.101397  73750.073850
# month_sin     -0.005454      0.709544      1.000000
# vwap       35065.923039  45255.098909  72685.022832
# atr         1066.568076   1658.500777   3979.835075
# ema        35522.855914  44755.106895  69548.468944

# %%
n = len(bitcoin)
# Split 70:20:10 (train:validation:test)
train_df = bitcoin[14:int(n*0.7)]
val_df = bitcoin[int(n*0.7):int(n*0.9)]
test_df = bitcoin[int(n*0.9):]

# %%
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()
scaler.fit(train_df)
train_df[train_df.columns] = scaler.transform(train_df[train_df.columns])
val_df[val_df.columns] = scaler.transform(val_df[val_df.columns])
test_df[test_df.columns] = scaler.transform(test_df[test_df.columns])

# %%
class DataWindow():
    def __init__(self, input_width, label_width, shift, 
                 train_df=train_df, val_df=val_df, test_df=test_df, 
                 label_columns=None):
        
        self.train_df = train_df
        self.val_df = val_df
        self.test_df = test_df
        
        self.label_columns = label_columns
        if label_columns is not None:
            self.label_columns_indices = {name: i for i, name in enumerate(label_columns)}
        self.column_indices = {name: i for i, name in enumerate(train_df.columns)}
        
        self.input_width = input_width
        self.label_width = label_width
        self.shift = shift
        
        self.total_window_size = input_width + shift
        
        self.input_slice = slice(0, input_width)
        self.input_indices = np.arange(self.total_window_size)[self.input_slice]
        
        self.label_start = self.total_window_size - self.label_width
        self.labels_slice = slice(self.label_start, None)
        self.label_indices = np.arange(self.total_window_size)[self.labels_slice]
    
    def split_to_inputs_labels(self, features):
        inputs = features[:, self.input_slice, :]
        labels = features[:, self.labels_slice, :]
        if self.label_columns is not None:
            labels = tf.stack(
                [labels[:,:,self.column_indices[name]] for name in self.label_columns],
                axis=-1
            )
        inputs.set_shape([None, self.input_width, None])
        labels.set_shape([None, self.label_width, None])
        
        return inputs, labels
    
    def plot(self, model=None, plot_col='high', max_subplots=3):
        inputs, labels = self.sample_batch
        
        plt.figure(figsize=(12, 8))
        plot_col_index = self.column_indices[plot_col]
        max_n = min(max_subplots, len(inputs))
        
        for n in range(max_n):
            plt.subplot(3, 1, n+1)
            plt.ylabel(f'{plot_col} [scaled]')
            plt.plot(self.input_indices, inputs[n, :, plot_col_index],
                     label='Inputs', marker='.', zorder=-10)

            if self.label_columns:
              label_col_index = self.label_columns_indices.get(plot_col, None)
            else:
              label_col_index = plot_col_index

            if label_col_index is None:
              continue

            plt.scatter(self.label_indices, labels[n, :, label_col_index],
                        edgecolors='k', marker='s', label='Labels', c='green', s=64)
            if model is not None:
              predictions = model(inputs)
              plt.scatter(self.label_indices, predictions[n, :, label_col_index],
                          marker='X', edgecolors='k', label='Predictions',
                          c='red', s=64)

            if n == 0:
              plt.legend()

        plt.xlabel('Time (h)')
        
    def make_dataset(self, data):
        data = np.array(data, dtype=np.float32)
        ds = tf.keras.preprocessing.timeseries_dataset_from_array(
            data=data,
            targets=None,
            sequence_length=self.total_window_size,
            sequence_stride=1,
            shuffle=True,
            batch_size=32
        )
        
        ds = ds.map(self.split_to_inputs_labels)
        return ds
    
    @property
    def train(self):
        return self.make_dataset(self.train_df)
    
    @property
    def val(self):
        return self.make_dataset(self.val_df)
    
    @property
    def test(self):
        return self.make_dataset(self.test_df)
    
    @property
    def sample_batch(self):
        result = getattr(self, '_sample_batch', None)
        if result is None:
            result = next(iter(self.train))
            self._sample_batch = result
        return result

# %%
def compile_and_fit(model, window, patience=3, max_epochs=50):
    early_stopping = EarlyStopping(monitor='val_loss', patience=patience, mode='min')
    model.compile(loss=MeanSquaredError(), optimizer=Adam(), metrics=[MeanAbsoluteError()])
    history = model.fit(window.train, epochs=max_epochs, validation_data=window.val, callbacks=[early_stopping])
    return history

# %%
wide_window = DataWindow(input_width=30, label_width=30, shift=1, label_columns=['high'])

# %%
lstm_model = Sequential([
    LSTM(32, return_sequences=True),
    # LSTM(128, return_sequences=True),
    # LSTM(32, return_sequences=True),
    Dense(units=1, kernel_initializer=tf.initializers.zeros)
    ])

# %%
history = compile_and_fit(lstm_model, wide_window)
val_performance = {}
performance = {}
val_performance['LSTM'] = lstm_model.evaluate(wide_window.val)
performance['LSTM'] = lstm_model.evaluate(wide_window.test, verbose=0)
# Out:
# Epoch 1/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 2s 51ms/step - loss: 0.1390 - mean_absolute_error: 0.2725 - val_loss: 1.7510 - val_mean_absolute_error: 1.2559
# Epoch 2/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.1268 - mean_absolute_error: 0.2586 - val_loss: 1.4658 - val_mean_absolute_error: 1.1441
# Epoch 3/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0827 - mean_absolute_error: 0.2027 - val_loss: 1.0756 - val_mean_absolute_error: 0.9655
# Epoch 4/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0430 - mean_absolute_error: 0.1563 - val_loss: 0.7514 - val_mean_absolute_error: 0.7837
# Epoch 5/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0323 - mean_absolute_error: 0.1454 - val_loss: 0.6618 - val_mean_absolute_error: 0.7315
# Epoch 6/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0180 - mean_absolute_error: 0.0994 - val_loss: 0.5720 - val_mean_absolute_error: 0.6756
# Epoch 7/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0143 - mean_absolute_error: 0.0806 - val_loss: 0.4369 - val_mean_absolute_error: 0.5683
# Epoch 8/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0100 - mean_absolute_error: 0.0687 - val_loss: 0.3632 - val_mean_absolute_error: 0.5043
# Epoch 9/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0107 - mean_absolute_error: 0.0683 - val_loss: 0.3437 - val_mean_absolute_error: 0.4903
# Epoch 10/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0087 - mean_absolute_error: 0.0597 - val_loss: 0.3185 - val_mean_absolute_error: 0.4674
# Epoch 11/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0082 - mean_absolute_error: 0.0587 - val_loss: 0.3012 - val_mean_absolute_error: 0.4524
# Epoch 12/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0083 - mean_absolute_error: 0.0591 - val_loss: 0.2952 - val_mean_absolute_error: 0.4494
# Epoch 13/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0073 - mean_absolute_error: 0.0558 - val_loss: 0.2875 - val_mean_absolute_error: 0.4434
# Epoch 14/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0077 - mean_absolute_error: 0.0570 - val_loss: 0.2778 - val_mean_absolute_error: 0.4348
# Epoch 15/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0072 - mean_absolute_error: 0.0546 - val_loss: 0.2696 - val_mean_absolute_error: 0.4278
# Epoch 16/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0069 - mean_absolute_error: 0.0532 - val_loss: 0.2604 - val_mean_absolute_error: 0.4196
# Epoch 17/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0064 - mean_absolute_error: 0.0519 - val_loss: 0.2528 - val_mean_absolute_error: 0.4129
# Epoch 18/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0058 - mean_absolute_error: 0.0497 - val_loss: 0.2464 - val_mean_absolute_error: 0.4078
# Epoch 19/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0064 - mean_absolute_error: 0.0510 - val_loss: 0.2393 - val_mean_absolute_error: 0.4017
# Epoch 20/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0052 - mean_absolute_error: 0.0471 - val_loss: 0.2349 - val_mean_absolute_error: 0.3984
# Epoch 21/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0051 - mean_absolute_error: 0.0466 - val_loss: 0.2256 - val_mean_absolute_error: 0.3893
# Epoch 22/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0055 - mean_absolute_error: 0.0477 - val_loss: 0.2223 - val_mean_absolute_error: 0.3875
# Epoch 23/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0055 - mean_absolute_error: 0.0469 - val_loss: 0.2145 - val_mean_absolute_error: 0.3800
# Epoch 24/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0052 - mean_absolute_error: 0.0465 - val_loss: 0.2093 - val_mean_absolute_error: 0.3754
# Epoch 25/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0048 - mean_absolute_error: 0.0441 - val_loss: 0.2022 - val_mean_absolute_error: 0.3683
# Epoch 26/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0048 - mean_absolute_error: 0.0444 - val_loss: 0.1956 - val_mean_absolute_error: 0.3618
# Epoch 27/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0046 - mean_absolute_error: 0.0426 - val_loss: 0.1922 - val_mean_absolute_error: 0.3592
# Epoch 28/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0044 - mean_absolute_error: 0.0422 - val_loss: 0.1844 - val_mean_absolute_error: 0.3508
# Epoch 29/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0042 - mean_absolute_error: 0.0414 - val_loss: 0.1807 - val_mean_absolute_error: 0.3477
# Epoch 30/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0041 - mean_absolute_error: 0.0412 - val_loss: 0.1753 - val_mean_absolute_error: 0.3424
# Epoch 31/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0043 - mean_absolute_error: 0.0414 - val_loss: 0.1693 - val_mean_absolute_error: 0.3362
# Epoch 32/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0042 - mean_absolute_error: 0.0413 - val_loss: 0.1657 - val_mean_absolute_error: 0.3333
# Epoch 33/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0040 - mean_absolute_error: 0.0401 - val_loss: 0.1589 - val_mean_absolute_error: 0.3257
# Epoch 34/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0036 - mean_absolute_error: 0.0388 - val_loss: 0.1547 - val_mean_absolute_error: 0.3219
# Epoch 35/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0038 - mean_absolute_error: 0.0389 - val_loss: 0.1502 - val_mean_absolute_error: 0.3175
# Epoch 36/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0037 - mean_absolute_error: 0.0383 - val_loss: 0.1449 - val_mean_absolute_error: 0.3115
# Epoch 37/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0034 - mean_absolute_error: 0.0373 - val_loss: 0.1412 - val_mean_absolute_error: 0.3078
# Epoch 38/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0033 - mean_absolute_error: 0.0366 - val_loss: 0.1371 - val_mean_absolute_error: 0.3033
# Epoch 39/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0034 - mean_absolute_error: 0.0371 - val_loss: 0.1340 - val_mean_absolute_error: 0.3001
# Epoch 40/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0034 - mean_absolute_error: 0.0367 - val_loss: 0.1290 - val_mean_absolute_error: 0.2939
# Epoch 41/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0035 - mean_absolute_error: 0.0368 - val_loss: 0.1272 - val_mean_absolute_error: 0.2925
# Epoch 42/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0032 - mean_absolute_error: 0.0356 - val_loss: 0.1222 - val_mean_absolute_error: 0.2860
# Epoch 43/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0034 - mean_absolute_error: 0.0365 - val_loss: 0.1211 - val_mean_absolute_error: 0.2856
# Epoch 44/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0032 - mean_absolute_error: 0.0358 - val_loss: 0.1160 - val_mean_absolute_error: 0.2786
# Epoch 45/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0030 - mean_absolute_error: 0.0345 - val_loss: 0.1145 - val_mean_absolute_error: 0.2772
# Epoch 46/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0030 - mean_absolute_error: 0.0349 - val_loss: 0.1099 - val_mean_absolute_error: 0.2709
# Epoch 47/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0028 - mean_absolute_error: 0.0338 - val_loss: 0.1090 - val_mean_absolute_error: 0.2704
# Epoch 48/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0028 - mean_absolute_error: 0.0336 - val_loss: 0.1049 - val_mean_absolute_error: 0.2645
# Epoch 49/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0027 - mean_absolute_error: 0.0332 - val_loss: 0.1043 - val_mean_absolute_error: 0.2644
# Epoch 50/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0027 - mean_absolute_error: 0.0331 - val_loss: 0.1001 - val_mean_absolute_error: 0.2581
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.1023 - mean_absolute_error: 0.2624

# %%
wide_window.plot(lstm_model)

# %%
print(val_performance['LSTM'][1])
print(performance['LSTM'][1])
# Out:
# 0.2580718696117401
# 0.32736554741859436
