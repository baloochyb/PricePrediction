# %%
import datetime

import numpy as np
import pandas as pd
import pandas_ta as ta
import seaborn as sns
import tensorflow as tf
import matplotlib.pyplot as plt

from tensorflow.keras import Model, Sequential

from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.losses import MeanSquaredError
from tensorflow.keras.metrics import MeanAbsoluteError

from tensorflow.keras.layers import Dense, Conv1D, LSTM, Lambda, Reshape, RNN, LSTMCell
from sklearn.preprocessing import MinMaxScaler

import warnings
warnings.filterwarnings('ignore')

# %%
tf.random.set_seed(42)
np.random.seed(42)

# %%
bitcoin = pd.read_csv('Bitcoin2.csv', sep=';')
bitcoin = bitcoin.iloc[::-1].reset_index(drop=True)

# %%
bitcoin.set_index(pd.DatetimeIndex(bitcoin["timeHigh"]), inplace=True)
vwap = ta.vwap(high=bitcoin['high'], low=bitcoin['low'], close=bitcoin['close'], volume=bitcoin['volume'])

atr = ta.atr(low=bitcoin['low'], high=bitcoin['high'], close=bitcoin['close'], length=14)
ema = ta.ema(close=bitcoin['close'], length=9)

# %%
cols_to_drop = ['timeOpen', 'timeClose', 'timeLow', 'timestamp', 'name', 'marketCap']
bitcoin = bitcoin.drop(cols_to_drop, axis=1)

# %% [markdown]
# Identifying the seasonal period using Fourier transform

# %%
fft = tf.signal.rfft(bitcoin['high'])
f_per_dataset = np.arange(0, len(fft))
n_sample_d = len(bitcoin['high'])
days_per_month = 30
months_per_dataset = n_sample_d / days_per_month
f_per_month = f_per_dataset / months_per_dataset

plt.step(f_per_month, np.abs(fft))
plt.xscale('log')
plt.xticks([1, 30], ['1/month', '1/day'])
plt.xlabel('Frequency')
plt.tight_layout()
plt.show()

# %%
timestamp_s = pd.to_datetime(bitcoin['timeHigh']).map(datetime.datetime.timestamp)
month = 30 * 24 * 60 * 60
bitcoin['month_sin'] = (np.sin(timestamp_s * (2*np.pi/month))).values
bitcoin = bitcoin.drop(['timeHigh'], axis=1)

bitcoin['vwap'] = vwap.values
bitcoin = bitcoin.drop(['volume'], axis=1)
bitcoin['atr'] = atr.values
bitcoin = bitcoin.drop(['low'], axis=1)
bitcoin['ema'] = ema.values
bitcoin = bitcoin.drop(['close'], axis=1)
bitcoin = bitcoin.drop(['open'], axis=1)

# %%
bitcoin.describe().transpose()
# Out:
#            count          mean           std           min           25%  \
# high       364.0  40681.358679  14962.167850  25735.308542  28040.592870
# month_sin  364.0     -0.008517      0.706835     -0.999898     -0.715739
# vwap       364.0  39962.236203  14482.278428  25325.633256  27623.187570
# atr        350.0   1441.826629    979.760619    486.006616    688.793676
# ema        356.0  39910.946035  14344.252567  25808.192306  27428.031445
#
#                     50%           75%           max
# high       35710.173965  46678.101397  73750.073850
# month_sin     -0.005454      0.709544      1.000000
# vwap       35065.923039  45255.098909  72685.022832
# atr         1066.568076   1658.500777   3979.835075
# ema        35522.855914  44755.106895  69548.468944

# %%
n = len(bitcoin)
# Split 70:20:10 (train:validation:test)
train_df = bitcoin[14:int(n*0.7)]
val_df = bitcoin[int(n*0.7):int(n*0.9)]
test_df = bitcoin[int(n*0.9):]

# %%
scaler = MinMaxScaler()
scaler.fit(train_df)
train_df[train_df.columns] = scaler.transform(train_df[train_df.columns])
val_df[val_df.columns] = scaler.transform(val_df[val_df.columns])
test_df[test_df.columns] = scaler.transform(test_df[test_df.columns])

# %%
class DataWindow():
    def __init__(self, input_width, label_width, shift, 
                 train_df=train_df, val_df=val_df, test_df=test_df, 
                 label_columns=None):
        
        self.train_df = train_df
        self.val_df = val_df
        self.test_df = test_df
        
        self.label_columns = label_columns
        if label_columns is not None:
            self.label_columns_indices = {name: i for i, name in enumerate(label_columns)}
        self.column_indices = {name: i for i, name in enumerate(train_df.columns)}
        
        self.input_width = input_width
        self.label_width = label_width
        self.shift = shift
        
        self.total_window_size = input_width + shift
        
        self.input_slice = slice(0, input_width)
        self.input_indices = np.arange(self.total_window_size)[self.input_slice]
        
        self.label_start = self.total_window_size - self.label_width
        self.labels_slice = slice(self.label_start, None)
        self.label_indices = np.arange(self.total_window_size)[self.labels_slice]
    
    def split_to_inputs_labels(self, features):
        inputs = features[:, self.input_slice, :]
        labels = features[:, self.labels_slice, :]
        if self.label_columns is not None:
            labels = tf.stack(
                [labels[:,:,self.column_indices[name]] for name in self.label_columns],
                axis=-1
            )
        inputs.set_shape([None, self.input_width, None])
        labels.set_shape([None, self.label_width, None])
        
        return inputs, labels
    
    def plot(self, model=None, plot_col='high', max_subplots=3):
        inputs, labels = self.sample_batch
        
        plt.figure(figsize=(12, 8))
        plot_col_index = self.column_indices[plot_col]
        max_n = min(max_subplots, len(inputs))
        
        for n in range(max_n):
            plt.subplot(3, 1, n+1)
            plt.ylabel(f'{plot_col} [scaled]')
            plt.plot(self.input_indices, inputs[n, :, plot_col_index],
                     label='Inputs', marker='.', zorder=-10)

            if self.label_columns:
              label_col_index = self.label_columns_indices.get(plot_col, None)
            else:
              label_col_index = plot_col_index

            if label_col_index is None:
              continue

            plt.scatter(self.label_indices, labels[n, :, label_col_index],
                        edgecolors='k', marker='s', label='Labels', c='green', s=64)
            if model is not None:
              predictions = model(inputs)
              plt.scatter(self.label_indices, predictions[n, :, label_col_index],
                          marker='X', edgecolors='k', label='Predictions',
                          c='red', s=64)

            if n == 0:
              plt.legend()

        plt.xlabel('Time (h)')
        
    def make_dataset(self, data):
        data = np.array(data, dtype=np.float32)
        ds = tf.keras.preprocessing.timeseries_dataset_from_array(
            data=data,
            targets=None,
            sequence_length=self.total_window_size,
            sequence_stride=1,
            shuffle=True,
            batch_size=32
        )
        
        ds = ds.map(self.split_to_inputs_labels)
        return ds
    
    @property
    def train(self):
        return self.make_dataset(self.train_df)
    
    @property
    def val(self):
        return self.make_dataset(self.val_df)
    
    @property
    def test(self):
        return self.make_dataset(self.test_df)
    
    @property
    def sample_batch(self):
        result = getattr(self, '_sample_batch', None)
        if result is None:
            result = next(iter(self.train))
            self._sample_batch = result
        return result

# %%
def compile_and_fit(model, window, patience=3, max_epochs=50):
    early_stopping = EarlyStopping(monitor='val_loss', patience=patience, mode='min')
    model.compile(loss=MeanSquaredError(), optimizer=Adam(), metrics=[MeanAbsoluteError()])
    history = model.fit(window.train, epochs=max_epochs, validation_data=window.val, callbacks=[early_stopping])
    return history

# %%
KERNEL_WIDTH = 3
conv_window = DataWindow(input_width=KERNEL_WIDTH, label_width=1, shift=1, label_columns=['high'])

LABEL_WIDTH = 30
INPUT_WIDTH = LABEL_WIDTH + KERNEL_WIDTH - 1
wide_conv_window = DataWindow(input_width=INPUT_WIDTH, label_width=LABEL_WIDTH, shift=1, label_columns=['high'])

# %% [markdown]
# ## CNN

# %%
cnn_model = Sequential([
    Conv1D(filters=32,
           kernel_size=(KERNEL_WIDTH,),
           activation='relu'),
    Dense(units=32, activation='relu'),
    Dense(units=1, kernel_initializer=tf.initializers.zeros)
])

# %%
history = compile_and_fit(cnn_model, conv_window)
val_performance = {}
performance = {}
val_performance['CNN'] = cnn_model.evaluate(conv_window.val)
performance['CNN'] = cnn_model.evaluate(conv_window.test, verbose=0)
# Out:
# Epoch 1/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 0.1560 - mean_absolute_error: 0.2842 - val_loss: 1.8569 - val_mean_absolute_error: 1.2750
# Epoch 2/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.1314 - mean_absolute_error: 0.2585 - val_loss: 1.5449 - val_mean_absolute_error: 1.1593
# Epoch 3/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1140 - mean_absolute_error: 0.2382 - val_loss: 1.0476 - val_mean_absolute_error: 0.9474
# Epoch 4/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0665 - mean_absolute_error: 0.1849 - val_loss: 0.4554 - val_mean_absolute_error: 0.6090
# Epoch 5/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0266 - mean_absolute_error: 0.1305 - val_loss: 0.0880 - val_mean_absolute_error: 0.2457
# Epoch 6/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0189 - mean_absolute_error: 0.1184 - val_loss: 0.0411 - val_mean_absolute_error: 0.1612
# Epoch 7/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0139 - mean_absolute_error: 0.1017 - val_loss: 0.0695 - val_mean_absolute_error: 0.2219
# Epoch 8/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0085 - mean_absolute_error: 0.0792 - val_loss: 0.0632 - val_mean_absolute_error: 0.2123
# Epoch 9/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0062 - mean_absolute_error: 0.0656 - val_loss: 0.0230 - val_mean_absolute_error: 0.1130
# Epoch 10/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0043 - mean_absolute_error: 0.0535 - val_loss: 0.0164 - val_mean_absolute_error: 0.0964
# Epoch 11/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0034 - mean_absolute_error: 0.0465 - val_loss: 0.0189 - val_mean_absolute_error: 0.1041
# Epoch 12/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0031 - mean_absolute_error: 0.0420 - val_loss: 0.0169 - val_mean_absolute_error: 0.0978
# Epoch 13/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0029 - mean_absolute_error: 0.0385 - val_loss: 0.0140 - val_mean_absolute_error: 0.0883
# Epoch 14/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0023 - mean_absolute_error: 0.0356 - val_loss: 0.0146 - val_mean_absolute_error: 0.0898
# Epoch 15/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0018 - mean_absolute_error: 0.0318 - val_loss: 0.0131 - val_mean_absolute_error: 0.0855
# Epoch 16/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0022 - mean_absolute_error: 0.0335 - val_loss: 0.0130 - val_mean_absolute_error: 0.0855
# Epoch 17/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0018 - mean_absolute_error: 0.0301 - val_loss: 0.0159 - val_mean_absolute_error: 0.0919
# Epoch 18/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0017 - mean_absolute_error: 0.0297 - val_loss: 0.0125 - val_mean_absolute_error: 0.0864
# Epoch 19/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0015 - mean_absolute_error: 0.0296 - val_loss: 0.0133 - val_mean_absolute_error: 0.0862
# Epoch 20/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0016 - mean_absolute_error: 0.0287 - val_loss: 0.0125 - val_mean_absolute_error: 0.0839
# Epoch 21/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0018 - mean_absolute_error: 0.0286 - val_loss: 0.0137 - val_mean_absolute_error: 0.0856
# Epoch 22/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0017 - mean_absolute_error: 0.0280 - val_loss: 0.0114 - val_mean_absolute_error: 0.0809
# Epoch 23/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0018 - mean_absolute_error: 0.0298 - val_loss: 0.0120 - val_mean_absolute_error: 0.0803
# Epoch 24/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0018 - mean_absolute_error: 0.0285 - val_loss: 0.0103 - val_mean_absolute_error: 0.0758
# Epoch 25/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0017 - mean_absolute_error: 0.0285 - val_loss: 0.0096 - val_mean_absolute_error: 0.0735
# Epoch 26/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0013 - mean_absolute_error: 0.0252 - val_loss: 0.0106 - val_mean_absolute_error: 0.0756
# Epoch 27/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0018 - mean_absolute_error: 0.0291 - val_loss: 0.0097 - val_mean_absolute_error: 0.0732
# Epoch 28/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0016 - mean_absolute_error: 0.0286 - val_loss: 0.0105 - val_mean_absolute_error: 0.0751
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step - loss: 0.0110 - mean_absolute_error: 0.0770

# %%
wide_conv_window.plot(cnn_model)

# %%
print(val_performance['CNN'][1])
print(performance['CNN'][1])
# Out:
# 0.07508525997400284
# 0.06295552104711533

# %% [markdown]
# ## CNN & LSTM

# %%
cnn_lstm_model = Sequential([
    Conv1D(filters=32,
           kernel_size=(KERNEL_WIDTH,),
           activation='relu'),
    LSTM(32, return_sequences=True),
    LSTM(32, return_sequences=True),
    Dense(units=1, kernel_initializer=tf.initializers.zeros)
])

# %%
history = compile_and_fit(cnn_lstm_model, conv_window)
val_performance['CNN + LSTM'] = cnn_lstm_model.evaluate(conv_window.val)
performance['CNN + LSTM'] = cnn_lstm_model.evaluate(conv_window.test, verbose=0)
# Out:
# Epoch 1/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 2s 28ms/step - loss: 0.1785 - mean_absolute_error: 0.3113 - val_loss: 1.9941 - val_mean_absolute_error: 1.3221
# Epoch 2/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.1651 - mean_absolute_error: 0.2919 - val_loss: 1.9318 - val_mean_absolute_error: 1.2995
# Epoch 3/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1597 - mean_absolute_error: 0.2858 - val_loss: 1.8091 - val_mean_absolute_error: 1.2543
# Epoch 4/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.1248 - mean_absolute_error: 0.2415 - val_loss: 1.5724 - val_mean_absolute_error: 1.1619
# Epoch 5/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0915 - mean_absolute_error: 0.2054 - val_loss: 1.1867 - val_mean_absolute_error: 0.9905
# Epoch 6/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0476 - mean_absolute_error: 0.1623 - val_loss: 0.7487 - val_mean_absolute_error: 0.7458
# Epoch 7/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0308 - mean_absolute_error: 0.1521 - val_loss: 0.5253 - val_mean_absolute_error: 0.5895
# Epoch 8/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0266 - mean_absolute_error: 0.1444 - val_loss: 0.5138 - val_mean_absolute_error: 0.5865
# Epoch 9/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0182 - mean_absolute_error: 0.1189 - val_loss: 0.5044 - val_mean_absolute_error: 0.5866
# Epoch 10/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0107 - mean_absolute_error: 0.0865 - val_loss: 0.3899 - val_mean_absolute_error: 0.4976
# Epoch 11/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0064 - mean_absolute_error: 0.0684 - val_loss: 0.3199 - val_mean_absolute_error: 0.4402
# Epoch 12/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0036 - mean_absolute_error: 0.0486 - val_loss: 0.2957 - val_mean_absolute_error: 0.4203
# Epoch 13/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0030 - mean_absolute_error: 0.0397 - val_loss: 0.2787 - val_mean_absolute_error: 0.4061
# Epoch 14/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0023 - mean_absolute_error: 0.0342 - val_loss: 0.2656 - val_mean_absolute_error: 0.3966
# Epoch 15/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0022 - mean_absolute_error: 0.0347 - val_loss: 0.2767 - val_mean_absolute_error: 0.4044
# Epoch 16/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0026 - mean_absolute_error: 0.0372 - val_loss: 0.2827 - val_mean_absolute_error: 0.4096
# Epoch 17/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0027 - mean_absolute_error: 0.0374 - val_loss: 0.2896 - val_mean_absolute_error: 0.4151
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step - loss: 0.2938 - mean_absolute_error: 0.4184

# %%
wide_conv_window.plot(cnn_model)

# %%
print(val_performance['CNN + LSTM'][1])
print(performance['CNN + LSTM'][1])
# Out:
# 0.41508734226226807
# 0.6784711480140686
