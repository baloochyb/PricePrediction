# %%
import datetime

import numpy as np
import pandas as pd
import pandas_ta as ta
import seaborn as sns
import tensorflow as tf
import matplotlib.pyplot as plt

from tensorflow.keras import Model, Sequential

from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.losses import MeanSquaredError
from tensorflow.keras.metrics import MeanAbsoluteError

from tensorflow.keras.layers import Dense, Conv1D, LSTM, Lambda, Reshape, RNN, LSTMCell
from sklearn.preprocessing import MinMaxScaler

import warnings
warnings.filterwarnings('ignore')

# %%
bitcoin = pd.read_csv('Bitcoin2.csv', sep=';')
bitcoin = bitcoin.iloc[::-1].reset_index(drop=True)

# %%
bitcoin.set_index(pd.DatetimeIndex(bitcoin["timeHigh"]), inplace=True)
vwap = ta.vwap(high=bitcoin['high'], low=bitcoin['low'], close=bitcoin['close'], volume=bitcoin['volume'])

atr = ta.atr(low=bitcoin['low'], high=bitcoin['high'], close=bitcoin['close'], length=14)
ema = ta.ema(close=bitcoin['close'], length=9)

# %%
cols_to_drop = ['timeOpen', 'timeClose', 'timeLow', 'timestamp', 'name', 'marketCap']
bitcoin = bitcoin.drop(cols_to_drop, axis=1)

# %%
timestamp_s = pd.to_datetime(bitcoin['timeHigh']).map(datetime.datetime.timestamp)
month = 30 * 24 * 60 * 60
bitcoin['month_sin'] = (np.sin(timestamp_s * (2*np.pi/month))).values
bitcoin = bitcoin.drop(['timeHigh'], axis=1)

bitcoin['vwap'] = vwap.values
bitcoin = bitcoin.drop(['volume'], axis=1)
bitcoin['atr'] = atr.values
bitcoin = bitcoin.drop(['low'], axis=1)
bitcoin['ema'] = ema.values
bitcoin = bitcoin.drop(['close'], axis=1)
bitcoin = bitcoin.drop(['open'], axis=1)

# %%
bitcoin.describe().transpose()
# Out:
#            count          mean           std           min           25%  \
# high       364.0  40681.358679  14962.167850  25735.308542  28040.592870
# month_sin  364.0     -0.008517      0.706835     -0.999898     -0.715739
# vwap       364.0  39962.236203  14482.278428  25325.633256  27623.187570
# atr        350.0   1441.826629    979.760619    486.006616    688.793676
# ema        356.0  39910.946035  14344.252567  25808.192306  27428.031445
#
#                     50%           75%           max
# high       35710.173965  46678.101397  73750.073850
# month_sin     -0.005454      0.709544      1.000000
# vwap       35065.923039  45255.098909  72685.022832
# atr         1066.568076   1658.500777   3979.835075
# ema        35522.855914  44755.106895  69548.468944

# %%
n = len(bitcoin)
# Split 70:20:10 (train:validation:test)
train_df = bitcoin[14:int(n*0.7)]
val_df = bitcoin[int(n*0.7):int(n*0.9)]
test_df = bitcoin[int(n*0.9):]

# %%
scaler = MinMaxScaler()
scaler.fit(train_df)
train_df[train_df.columns] = scaler.transform(train_df[train_df.columns])
val_df[val_df.columns] = scaler.transform(val_df[val_df.columns])
test_df[test_df.columns] = scaler.transform(test_df[test_df.columns])

# %%
class DataWindow():
    def __init__(self, input_width, label_width, shift, 
                 train_df=train_df, val_df=val_df, test_df=test_df, 
                 label_columns=None):
        
        self.train_df = train_df
        self.val_df = val_df
        self.test_df = test_df
        
        self.label_columns = label_columns
        if label_columns is not None:
            self.label_columns_indices = {name: i for i, name in enumerate(label_columns)}
        self.column_indices = {name: i for i, name in enumerate(train_df.columns)}
        
        self.input_width = input_width
        self.label_width = label_width
        self.shift = shift
        
        self.total_window_size = input_width + shift
        
        self.input_slice = slice(0, input_width)
        self.input_indices = np.arange(self.total_window_size)[self.input_slice]
        
        self.label_start = self.total_window_size - self.label_width
        self.labels_slice = slice(self.label_start, None)
        self.label_indices = np.arange(self.total_window_size)[self.labels_slice]
    
    def split_to_inputs_labels(self, features):
        inputs = features[:, self.input_slice, :]
        labels = features[:, self.labels_slice, :]
        if self.label_columns is not None:
            labels = tf.stack(
                [labels[:,:,self.column_indices[name]] for name in self.label_columns],
                axis=-1
            )
        inputs.set_shape([None, self.input_width, None])
        labels.set_shape([None, self.label_width, None])
        
        return inputs, labels
    
    def plot(self, model=None, plot_col='high', max_subplots=3):
        inputs, labels = self.sample_batch
        
        plt.figure(figsize=(12, 8))
        plot_col_index = self.column_indices[plot_col]
        max_n = min(max_subplots, len(inputs))
        
        for n in range(max_n):
            plt.subplot(3, 1, n+1)
            plt.ylabel(f'{plot_col} [scaled]')
            plt.plot(self.input_indices, inputs[n, :, plot_col_index],
                     label='Inputs', marker='.', zorder=-10)

            if self.label_columns:
              label_col_index = self.label_columns_indices.get(plot_col, None)
            else:
              label_col_index = plot_col_index

            if label_col_index is None:
              continue

            plt.scatter(self.label_indices, labels[n, :, label_col_index],
                        edgecolors='k', marker='s', label='Labels', c='green', s=64)
            if model is not None:
              predictions = model(inputs)
              plt.scatter(self.label_indices, predictions[n, :, label_col_index],
                          marker='X', edgecolors='k', label='Predictions',
                          c='red', s=64)

            if n == 0:
              plt.legend()

        plt.xlabel('Time (h)')
        
    def make_dataset(self, data):
        data = np.array(data, dtype=np.float32)
        ds = tf.keras.preprocessing.timeseries_dataset_from_array(
            data=data,
            targets=None,
            sequence_length=self.total_window_size,
            sequence_stride=1,
            shuffle=True,
            batch_size=32
        )
        
        ds = ds.map(self.split_to_inputs_labels)
        return ds
    
    @property
    def train(self):
        return self.make_dataset(self.train_df)
    
    @property
    def val(self):
        return self.make_dataset(self.val_df)
    
    @property
    def test(self):
        return self.make_dataset(self.test_df)
    
    @property
    def sample_batch(self):
        result = getattr(self, '_sample_batch', None)
        if result is None:
            result = next(iter(self.train))
            self._sample_batch = result
        return result

# %%
def compile_and_fit(model, window, patience=3, max_epochs=50):
    early_stopping = EarlyStopping(monitor='val_loss', patience=patience, mode='min')
    model.compile(loss=MeanSquaredError(), optimizer=Adam(), metrics=[MeanAbsoluteError()])
    history = model.fit(window.train, epochs=max_epochs, validation_data=window.val, callbacks=[early_stopping])
    return history

# %%
KERNEL_WIDTH = 3
conv_window = DataWindow(input_width=KERNEL_WIDTH, label_width=1, shift=1, label_columns=['high'])

LABEL_WIDTH = 30
INPUT_WIDTH = LABEL_WIDTH + KERNEL_WIDTH - 1
wide_conv_window = DataWindow(input_width=INPUT_WIDTH, label_width=LABEL_WIDTH, shift=1, label_columns=['high'])

# %% [markdown]
# ## CNN

# %%
cnn_model = Sequential([
    Conv1D(filters=32,
           kernel_size=(KERNEL_WIDTH,),
           activation='relu'),
    Dense(units=32, activation='relu'),
    Dense(units=1)
])

# %%
history = compile_and_fit(cnn_model, conv_window)
val_performance = {}
performance = {}
val_performance['CNN'] = cnn_model.evaluate(conv_window.val)
performance['CNN'] = cnn_model.evaluate(conv_window.test, verbose=0)
# Out:
# Epoch 1/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0150 - mean_absolute_error: 0.0846 - val_loss: 0.0227 - val_mean_absolute_error: 0.1247
# Epoch 2/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0045 - mean_absolute_error: 0.0539 - val_loss: 0.0157 - val_mean_absolute_error: 0.1011
# Epoch 3/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0028 - mean_absolute_error: 0.0384 - val_loss: 0.0252 - val_mean_absolute_error: 0.1202
# Epoch 4/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0022 - mean_absolute_error: 0.0341 - val_loss: 0.0143 - val_mean_absolute_error: 0.0983
# Epoch 5/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0021 - mean_absolute_error: 0.0361 - val_loss: 0.0153 - val_mean_absolute_error: 0.0961
# Epoch 6/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0016 - mean_absolute_error: 0.0285 - val_loss: 0.0140 - val_mean_absolute_error: 0.0904
# Epoch 7/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0016 - mean_absolute_error: 0.0272 - val_loss: 0.0120 - val_mean_absolute_error: 0.0846
# Epoch 8/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0014 - mean_absolute_error: 0.0254 - val_loss: 0.0122 - val_mean_absolute_error: 0.0834
# Epoch 9/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0014 - mean_absolute_error: 0.0250 - val_loss: 0.0118 - val_mean_absolute_error: 0.0819
# Epoch 10/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0016 - mean_absolute_error: 0.0284 - val_loss: 0.0104 - val_mean_absolute_error: 0.0781
# Epoch 11/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0016 - mean_absolute_error: 0.0262 - val_loss: 0.0109 - val_mean_absolute_error: 0.0771
# Epoch 12/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0011 - mean_absolute_error: 0.0227 - val_loss: 0.0090 - val_mean_absolute_error: 0.0733
# Epoch 13/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0011 - mean_absolute_error: 0.0234 - val_loss: 0.0100 - val_mean_absolute_error: 0.0727
# Epoch 14/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 9.9245e-04 - mean_absolute_error: 0.0215 - val_loss: 0.0074 - val_mean_absolute_error: 0.0647
# Epoch 15/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0012 - mean_absolute_error: 0.0237 - val_loss: 0.0078 - val_mean_absolute_error: 0.0627
# Epoch 16/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 7.5207e-04 - mean_absolute_error: 0.0191 - val_loss: 0.0065 - val_mean_absolute_error: 0.0588
# Epoch 17/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 9.5769e-04 - mean_absolute_error: 0.0206 - val_loss: 0.0072 - val_mean_absolute_error: 0.0604
# Epoch 18/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0012 - mean_absolute_error: 0.0214 - val_loss: 0.0070 - val_mean_absolute_error: 0.0595
# Epoch 19/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 9.6067e-04 - mean_absolute_error: 0.0200 - val_loss: 0.0056 - val_mean_absolute_error: 0.0567
# Epoch 20/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0010 - mean_absolute_error: 0.0245 - val_loss: 0.0087 - val_mean_absolute_error: 0.0652
# Epoch 21/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0012 - mean_absolute_error: 0.0224 - val_loss: 0.0055 - val_mean_absolute_error: 0.0558
# Epoch 22/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 9.3192e-04 - mean_absolute_error: 0.0220 - val_loss: 0.0058 - val_mean_absolute_error: 0.0549
# Epoch 23/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 6.2644e-04 - mean_absolute_error: 0.0178 - val_loss: 0.0054 - val_mean_absolute_error: 0.0555
# Epoch 24/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 7.5376e-04 - mean_absolute_error: 0.0205 - val_loss: 0.0070 - val_mean_absolute_error: 0.0590
# Epoch 25/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 8.4450e-04 - mean_absolute_error: 0.0199 - val_loss: 0.0059 - val_mean_absolute_error: 0.0553
# Epoch 26/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 8.6697e-04 - mean_absolute_error: 0.0204 - val_loss: 0.0052 - val_mean_absolute_error: 0.0540
# Epoch 27/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 7.6510e-04 - mean_absolute_error: 0.0199 - val_loss: 0.0054 - val_mean_absolute_error: 0.0530
# Epoch 28/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 8.5100e-04 - mean_absolute_error: 0.0202 - val_loss: 0.0059 - val_mean_absolute_error: 0.0539
# Epoch 29/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 8.5788e-04 - mean_absolute_error: 0.0195 - val_loss: 0.0051 - val_mean_absolute_error: 0.0526
# Epoch 30/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 9.9232e-04 - mean_absolute_error: 0.0205 - val_loss: 0.0051 - val_mean_absolute_error: 0.0521
# Epoch 31/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 6.7628e-04 - mean_absolute_error: 0.0185 - val_loss: 0.0058 - val_mean_absolute_error: 0.0531
# Epoch 32/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 8.2801e-04 - mean_absolute_error: 0.0196 - val_loss: 0.0050 - val_mean_absolute_error: 0.0516
# Epoch 33/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 8.1753e-04 - mean_absolute_error: 0.0200 - val_loss: 0.0053 - val_mean_absolute_error: 0.0516
# Epoch 34/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 6.7235e-04 - mean_absolute_error: 0.0183 - val_loss: 0.0058 - val_mean_absolute_error: 0.0531
# Epoch 35/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 7.8535e-04 - mean_absolute_error: 0.0188 - val_loss: 0.0049 - val_mean_absolute_error: 0.0513
# Epoch 36/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 6.4052e-04 - mean_absolute_error: 0.0172 - val_loss: 0.0049 - val_mean_absolute_error: 0.0517
# Epoch 37/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 7.9179e-04 - mean_absolute_error: 0.0189 - val_loss: 0.0049 - val_mean_absolute_error: 0.0525
# Epoch 38/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 7.7674e-04 - mean_absolute_error: 0.0192 - val_loss: 0.0047 - val_mean_absolute_error: 0.0514
# Epoch 39/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 6.3901e-04 - mean_absolute_error: 0.0178 - val_loss: 0.0050 - val_mean_absolute_error: 0.0509
# Epoch 40/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 6.0217e-04 - mean_absolute_error: 0.0171 - val_loss: 0.0048 - val_mean_absolute_error: 0.0510
# Epoch 41/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 7.3752e-04 - mean_absolute_error: 0.0192 - val_loss: 0.0047 - val_mean_absolute_error: 0.0518
# Epoch 42/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 8.1269e-04 - mean_absolute_error: 0.0203 - val_loss: 0.0066 - val_mean_absolute_error: 0.0563
# Epoch 43/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 6.7177e-04 - mean_absolute_error: 0.0186 - val_loss: 0.0052 - val_mean_absolute_error: 0.0515
# Epoch 44/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 8.7437e-04 - mean_absolute_error: 0.0199 - val_loss: 0.0052 - val_mean_absolute_error: 0.0578
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step - loss: 0.0053 - mean_absolute_error: 0.0573

# %%
wide_conv_window.plot(cnn_model)

# %%
print(val_performance['CNN'][1])
print(performance['CNN'][1])
# Out:
# 0.05780568718910217
# 0.11536937206983566

# %% [markdown]
# ## CNN & LSTM

# %%
cnn_lstm_model = Sequential([
    Conv1D(filters=32,
           kernel_size=(KERNEL_WIDTH,),
           activation='relu'),
    LSTM(32, return_sequences=True),
    LSTM(32, return_sequences=True),
    Dense(units=1)
])

# %%
history = compile_and_fit(cnn_lstm_model, conv_window)
val_performance['CNN + LSTM'] = cnn_lstm_model.evaluate(conv_window.val)
performance['CNN + LSTM'] = cnn_lstm_model.evaluate(conv_window.test, verbose=0)
# Out:
# Epoch 1/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 2s 43ms/step - loss: 0.1589 - mean_absolute_error: 0.2863 - val_loss: 1.8115 - val_mean_absolute_error: 1.2566
# Epoch 2/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.1365 - mean_absolute_error: 0.2597 - val_loss: 1.5347 - val_mean_absolute_error: 1.1502
# Epoch 3/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.1047 - mean_absolute_error: 0.2192 - val_loss: 1.1408 - val_mean_absolute_error: 0.9798
# Epoch 4/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0680 - mean_absolute_error: 0.1921 - val_loss: 0.6420 - val_mean_absolute_error: 0.7089
# Epoch 5/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0337 - mean_absolute_error: 0.1555 - val_loss: 0.2927 - val_mean_absolute_error: 0.4474
# Epoch 6/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0235 - mean_absolute_error: 0.1349 - val_loss: 0.1855 - val_mean_absolute_error: 0.3511
# Epoch 7/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0147 - mean_absolute_error: 0.1049 - val_loss: 0.1475 - val_mean_absolute_error: 0.3170
# Epoch 8/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0067 - mean_absolute_error: 0.0685 - val_loss: 0.0580 - val_mean_absolute_error: 0.1905
# Epoch 9/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0038 - mean_absolute_error: 0.0485 - val_loss: 0.0293 - val_mean_absolute_error: 0.1335
# Epoch 10/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0035 - mean_absolute_error: 0.0445 - val_loss: 0.0338 - val_mean_absolute_error: 0.1448
# Epoch 11/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0032 - mean_absolute_error: 0.0434 - val_loss: 0.0435 - val_mean_absolute_error: 0.1657
# Epoch 12/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0026 - mean_absolute_error: 0.0390 - val_loss: 0.0530 - val_mean_absolute_error: 0.1833
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step - loss: 0.0547 - mean_absolute_error: 0.1875

# %%
wide_conv_window.plot(cnn_model)

# %%
print(val_performance['CNN + LSTM'][1])
print(performance['CNN + LSTM'][1])
# Out:
# 0.18332746624946594
# 0.19168531894683838
